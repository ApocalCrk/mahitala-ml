# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import skew, kurtosis

# %%
df = pd.read_csv('../../dataset/crop_recommendation.csv')

df_numeric = df.drop(columns=['label'])

df_numeric
# Out:
#         N   P   K  temperature   humidity        ph    rainfall
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340
# ...   ...  ..  ..          ...        ...       ...         ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041
#
# [2200 rows x 7 columns]

# %%
df_numeric.hist(bins=10, figsize=(12, 8))
plt.suptitle('Histogram of Features')
plt.show()

# %%
for col in df_numeric.columns:
    print(f'{col} - Skewness: {skew(df_numeric[col])}, Kurtosis: {kurtosis(df_numeric[col])}')
# Out:
# N - Skewness: 0.5093737660143558, Kurtosis: -1.0585623483258277
# P - Skewness: 1.0100832494748144, Kurtosis: 0.8555987862061758
# K - Skewness: 2.373547499838119, Kurtosis: 4.436522649134237
# temperature - Skewness: 0.18480661982240237, Kurtosis: 1.2270293391502678
# humidity - Skewness: -1.090963432252511, Kurtosis: 0.29872180495931655
# ph - Skewness: 0.2837358126439414, Kurtosis: 1.6490951298476855
# rainfall - Skewness: 0.9650977586362035, Kurtosis: 0.6029744037684268
